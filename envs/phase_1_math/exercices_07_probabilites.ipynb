# %% [markdown]
# # 📝 Exercices : Probabilités Fondamentales
#
# ## 🎯 Objectifs
#
# Ces exercices couvrent tous les concepts du chapitre 07 :
# - Espaces de probabilité et événements
# - Probabilités conditionnelles
# - Théorème de Bayes
# - Variables aléatoires
# - Distributions de probabilité
# - Espérance et variance
# - Covariance et corrélation
#
# 💡 **Conseil** : Essayez de résoudre les exercices sans regarder les solutions !
#
# ---

# %%
# Imports nécessaires
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.special import comb
import pandas as pd

plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
np.random.seed(42)

# %% [markdown]
# ## Section 1 : Espaces de Probabilité 🎲
#
# ### Exercice 1.1 : Dé équilibré
#
# On lance un dé à 6 faces équilibré.
#
# **a)** Définir l'espace échantillonnal Ω
# **b)** Calculer P(nombre pair)
# **c)** Calculer P(nombre ≥ 4)
# **d)** Calculer P(nombre pair ∩ nombre ≥ 4)
# **e)** Calculer P(nombre pair ∪ nombre ≥ 4)

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 1.2 : Pièce truquée
#
# Une pièce de monnaie est truquée : P(Pile) = 0.6 et P(Face) = 0.4.
#
# **a)** On lance la pièce 2 fois. Quel est l'espace échantillonnal ?
# **b)** Calculer P(2 piles)
# **c)** Calculer P(au moins 1 pile)
# **d)** Calculer P(exactement 1 pile)

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 1.3 : Tirage de cartes
#
# On tire une carte d'un jeu de 52 cartes.
#
# **a)** Calculer P(As)
# **b)** Calculer P(Cœur)
# **c)** Calculer P(As ∪ Cœur)
# **d)** Calculer P(As ∩ Cœur)
# **e)** Vérifier : P(A ∪ B) = P(A) + P(B) - P(A ∩ B)

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 1.4 : Événements complémentaires
#
# Dans une population :
# - P(parle français) = 0.7
# - P(parle anglais) = 0.5
# - P(parle français ET anglais) = 0.3
#
# **a)** Calculer P(parle français OU anglais)
# **b)** Calculer P(ne parle ni français ni anglais)
# **c)** Calculer P(parle uniquement français)
# **d)** Calculer P(parle uniquement anglais)

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 1.5 : Simulation
#
# Simuler 10 000 lancers d'un dé équilibré.
#
# **a)** Vérifier empiriquement que P(face i) ≈ 1/6 pour chaque face
# **b)** Tracer un histogramme des résultats
# **c)** Calculer P(pair) empiriquement et comparer à la valeur théorique

# %%
# Votre code ici

# %% [markdown]
# ## Section 2 : Probabilités Conditionnelles 🔗
#
# ### Exercice 2.1 : Urne
#
# Une urne contient 5 boules rouges et 3 boules bleues. On tire 2 boules **sans remise**.
#
# **a)** Calculer P(1ère rouge)
# **b)** Calculer P(2ème rouge | 1ère rouge)
# **c)** Calculer P(2ème rouge | 1ère bleue)
# **d)** Calculer P(1ère rouge ∩ 2ème rouge)
# **e)** Calculer P(2ème rouge) en utilisant les probabilités totales

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 2.2 : Indépendance
#
# On lance 2 dés équilibrés.
#
# **a)** Les événements "1er dé = 6" et "2ème dé = 6" sont-ils indépendants ?
# **b)** Les événements "1er dé = 6" et "somme = 7" sont-ils indépendants ?
# **c)** Vérifier numériquement votre réponse pour (b)

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 2.3 : Famille
#
# Dans une famille de 2 enfants :
# - Ω = {GG, GF, FG, FF} (G=garçon, F=fille), équiprobables
#
# **a)** Calculer P(2 filles)
# **b)** Sachant qu'il y a au moins 1 fille, quelle est P(2 filles) ?
# **c)** Sachant que l'aîné est une fille, quelle est P(2 filles) ?
# **d)** Expliquer pourquoi (b) ≠ (c)

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 2.4 : Monty Hall Problem 🚗
#
# Jeu télévisé : 3 portes, une voiture derrière l'une, chèvres derrière les 2 autres.
# 1. Vous choisissez une porte
# 2. L'animateur ouvre une autre porte (avec chèvre)
# 3. Devez-vous changer de porte ?
#
# **a)** Calculer P(gagner | rester sur votre choix)
# **b)** Calculer P(gagner | changer de porte)
# **c)** Simuler 10 000 parties pour vérifier
# **d)** Conclusion : faut-il changer ?

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 2.5 : Formule des probabilités totales
#
# Une usine a 3 machines :
# - Machine A : produit 50% des pièces, 3% de défauts
# - Machine B : produit 30% des pièces, 5% de défauts
# - Machine C : produit 20% des pièces, 8% de défauts
#
# **a)** Calculer P(pièce défectueuse)
# **b)** Vérifier avec la formule des probabilités totales

# %%
# Votre code ici

# %% [markdown]
# ## Section 3 : Théorème de Bayes 🌟
#
# ### Exercice 3.1 : Test médical
#
# Maladie rare : prévalence 0.1%
# Test : sensibilité 99% (vrais positifs), spécificité 95% (vrais négatifs)
#
# **a)** Calculer P(Test+)
# **b)** Si test positif, quelle est P(Malade) ?
# **c)** Si test négatif, quelle est P(Sain) ?
# **d)** Interpréter les résultats

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 3.2 : Spam filtering
#
# Filtre anti-spam :
# - 40% des emails sont des spams
# - P(contient "viagra" | spam) = 0.75
# - P(contient "viagra" | ham) = 0.03
#
# **a)** Calculer P(contient "viagra")
# **b)** Si email contient "viagra", calculer P(spam)
# **c)** Si email ne contient pas "viagra", calculer P(spam)

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 3.3 : Mise à jour bayésienne séquentielle
#
# 3 boîtes :
# - Boîte 1 : 10 jetons (3 blancs, 7 noirs)
# - Boîte 2 : 10 jetons (5 blancs, 5 noirs)
# - Boîte 3 : 10 jetons (8 blancs, 2 noirs)
#
# On choisit une boîte au hasard (prior uniforme).
#
# **a)** On tire 1 jeton blanc. Calculer les posteriors P(Boîte i | blanc)
# **b)** On tire un 2ème jeton blanc. Mettre à jour les posteriors
# **c)** Tracer l'évolution des posteriors
# **d)** Quelle boîte est la plus probable ?

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 3.4 : Naive Bayes Classifier
#
# Classification de documents :
# - 60% Sport, 40% Politique
#
# Fréquence des mots :
# - P("match" | Sport) = 0.4, P("match" | Politique) = 0.1
# - P("élection" | Sport) = 0.05, P("élection" | Politique) = 0.35
#
# **a)** Document contient "match". Calculer P(Sport | "match")
# **b)** Document contient "match" et "élection". Sous hypothèse d'indépendance (Naive Bayes), calculer P(Sport | "match", "élection")
# **c)** Classifier le document

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 3.5 : Machine défectueuse (suite de 2.5)
#
# Reprendre les données de l'exercice 2.5.
#
# **a)** Sachant qu'une pièce est défectueuse, quelle est P(produite par machine A) ?
# **b)** Idem pour machines B et C
# **c)** Quelle machine a le plus probablement produit la pièce défectueuse ?

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 3.6 : Visualisation de Bayes
#
# Créer une visualisation interactive montrant :
#
# **a)** Prior, Likelihood, Evidence, Posterior (barres)
# **b)** Effet de changer le prior sur le posterior
# **c)** Effet de changer la likelihood sur le posterior

# %%
# Votre code ici

# %% [markdown]
# ## Section 4 : Variables Aléatoires 🎲
#
# ### Exercice 4.1 : VA discrète
#
# Soit X = somme de 2 dés.
#
# **a)** Déterminer toutes les valeurs possibles de X
# **b)** Calculer la PMF : P(X = k) pour tout k
# **c)** Tracer la PMF
# **d)** Calculer et tracer la CDF
# **e)** Vérifier que Σ P(X=k) = 1

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 4.2 : Fonction génératrice
#
# Soit X avec PMF : P(X=0)=0.2, P(X=1)=0.5, P(X=2)=0.3
#
# **a)** Implémenter une classe VariableAleatoire avec méthodes pmf() et cdf()
# **b)** Ajouter méthode simuler(n) qui génère n échantillons
# **c)** Simuler 10 000 échantillons et vérifier empiriquement la PMF

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 4.3 : Transformation de VA
#
# Soit X ~ Uniforme([0, 1]).
#
# **a)** Définir Y = 2X + 3. Quelle est la distribution de Y ?
# **b)** Définir Z = X². Quelle est la PDF de Z ?
# **c)** Simuler et vérifier graphiquement

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 4.4 : Quantiles
#
# Pour X ~ Normale(0, 1) :
#
# **a)** Calculer les quartiles (Q1, Q2, Q3)
# **b)** Calculer P(X > 1.96)
# **c)** Trouver x tel que P(X ≤ x) = 0.95
# **d)** Visualiser sur la PDF

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 4.5 : VA continues vs discrètes
#
# **a)** Pourquoi P(X = x) = 0 pour une VA continue ?
# **b)** Simuler X ~ Normale(0, 1) avec 10 000 points. Compter combien de fois X = 0 exactement
# **c)** Comparer P(|X| < 0.01) et P(X = 0)
# **d)** Expliquer la différence fondamentale

# %%
# Votre code ici

# %% [markdown]
# ## Section 5 : Distributions de Probabilité 📊
#
# ### Exercice 5.1 : Bernoulli et Binomiale
#
# Conversion d'un site web : p = 0.15
#
# **a)** Modéliser 1 visiteur avec une Bernoulli
# **b)** Pour 100 visiteurs, quelle est la distribution du nombre de conversions ?
# **c)** Calculer P(exactement 20 conversions)
# **d)** Calculer P(au moins 10 conversions)
# **e)** Simuler 1000 jours de 100 visiteurs et tracer l'histogramme

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 5.2 : Poisson
#
# Un serveur reçoit en moyenne λ = 5 requêtes par seconde.
#
# **a)** Modéliser avec une loi de Poisson
# **b)** Calculer P(exactement 3 requêtes en 1 sec)
# **c)** Calculer P(plus de 8 requêtes en 1 sec)
# **d)** En 10 secondes, quelle est la distribution ? (λ devient ?)
# **e)** Tracer la PMF pour différentes valeurs de λ

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 5.3 : Loi Normale
#
# QI : X ~ Normale(μ=100, σ²=225)
#
# **a)** Calculer P(X > 130) (QI "très supérieur")
# **b)** Calculer P(85 ≤ X ≤ 115)
# **c)** Trouver x tel que P(X > x) = 0.01 (top 1%)
# **d)** Visualiser avec zones colorées
# **e)** Simuler 10 000 personnes et vérifier empiriquement

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 5.4 : Approximation Binomiale → Normale
#
# X ~ Binomiale(n=100, p=0.5)
#
# **a)** Calculer E[X] et Var(X)
# **b)** Approximation normale : Y ~ Normale(E[X], Var(X))
# **c)** Comparer P(X ≤ 55) exacte vs approximation
# **d)** Tracer PMF binomiale et PDF normale sur même graphe
# **e)** Pour quel n l'approximation devient-elle bonne ?

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 5.5 : Q-Q Plot
#
# **a)** Générer 1000 échantillons de Normale(5, 4)
# **b)** Générer 1000 échantillons de Exponentielle(1)
# **c)** Générer 1000 échantillons de Uniforme(0, 10)
# **d)** Pour chaque, tracer un Q-Q plot contre la normale
# **e)** Interpréter : quelles distributions ressemblent à une normale ?

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 5.6 : Application Finance - Rendements
#
# Rendements journaliers d'une action : R ~ Normale(μ=0.0005, σ=0.02)
#
# **a)** Quelle est la probabilité de perdre de l'argent un jour donné ?
# **b)** Quelle est la probabilité de perdre plus de 5% en un jour ?
# **c)** Sur 252 jours (1 an), combien de jours de pertes attendus ?
# **d)** Simuler 1 an de trading et visualiser
# **e)** Calculer le rendement total annuel

# %%
# Votre code ici

# %% [markdown]
# ## Section 6 : Espérance et Variance 📐
#
# ### Exercice 6.1 : Calcul à la main
#
# X avec PMF : P(X=-1)=0.2, P(X=0)=0.5, P(X=2)=0.3
#
# **a)** Calculer E[X]
# **b)** Calculer E[X²]
# **c)** Calculer Var(X) avec E[X²] - (E[X])²
# **d)** Calculer Var(X) avec E[(X - E[X])²]
# **e)** Vérifier que les deux méthodes donnent le même résultat

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 6.2 : Propriétés de l'espérance
#
# X ~ Normale(3, 4)
#
# **a)** Calculer E[X]
# **b)** Calculer E[2X + 5] (théorique et par simulation)
# **c)** Calculer E[X²] (≠ (E[X])² !)
# **d)** Vérifier : E[aX + b] = aE[X] + b

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 6.3 : Propriétés de la variance
#
# X ~ Uniforme(0, 10)
#
# **a)** Calculer Var(X) théorique : (b-a)²/12
# **b)** Calculer Var(2X)
# **c)** Calculer Var(X + 5)
# **d)** Vérifier : Var(aX + b) = a²Var(X)
# **e)** Pourquoi la constante b disparaît ?

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 6.4 : Somme de VA indépendantes
#
# X ~ Normale(2, 9), Y ~ Normale(3, 16), X et Y indépendantes
#
# **a)** Calculer E[X + Y]
# **b)** Calculer Var(X + Y)
# **c)** Quelle est la distribution de X + Y ?
# **d)** Vérifier par simulation avec 10 000 échantillons
# **e)** Que se passe-t-il si X et Y ne sont pas indépendantes ?

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 6.5 : Moments d'ordre supérieur
#
# Générer 10 000 échantillons de chaque distribution :
# - Normale(0, 1)
# - Exponentielle(1)
# - Uniforme(-1, 1)
#
# **a)** Calculer skewness pour chaque
# **b)** Calculer kurtosis pour chaque
# **c)** Tracer les histogrammes avec annotations
# **d)** Interpréter les différences

# %%
# Votre code ici

# %% [markdown]
# ## Section 7 : Covariance et Corrélation 🔗
#
# ### Exercice 7.1 : Calcul de covariance
#
# Deux VA discrètes :
# - (X, Y) = (1, 2) avec p=0.3
# - (X, Y) = (2, 3) avec p=0.5
# - (X, Y) = (3, 1) avec p=0.2
#
# **a)** Calculer E[X] et E[Y]
# **b)** Calculer E[XY]
# **c)** Calculer Cov(X, Y) = E[XY] - E[X]E[Y]
# **d)** Interpréter le signe de la covariance

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 7.2 : Génération de données corrélées
#
# **a)** Générer X ~ Normale(0, 1)
# **b)** Générer Y = 0.8X + bruit, où bruit ~ Normale(0, 0.36)
# **c)** Calculer la corrélation théorique attendue
# **d)** Vérifier empiriquement avec 10 000 échantillons
# **e)** Tracer le scatter plot avec ligne de régression

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 7.3 : Corrélation ≠ Causalité
#
# **a)** Générer Z ~ Normale(0, 1)
# **b)** Définir X = Z + bruit1, Y = Z + bruit2 (bruits indépendants)
# **c)** Calculer Corr(X, Y)
# **d)** X et Y sont-elles indépendantes ?
# **e)** Expliquer : corrélation vient de la cause commune Z

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 7.4 : Matrice de covariance
#
# Vecteur aléatoire (X, Y, Z) avec :
# - X ~ Normale(0, 1)
# - Y ~ Normale(0, 4)
# - Z ~ Normale(0, 9)
# - Corr(X, Y) = 0.5
# - Corr(X, Z) = -0.3
# - Corr(Y, Z) = 0.7
#
# **a)** Construire la matrice de covariance Σ
# **b)** Vérifier que Σ est symétrique
# **c)** Vérifier que Σ est semi-définie positive (valeurs propres ≥ 0)
# **d)** Générer 1000 échantillons du vecteur (X, Y, Z)
# **e)** Calculer la matrice de covariance empirique et comparer

# %%
# Votre code ici

# %% [markdown]
# ### Exercice 7.5 : Application Finance - Diversification
#
# Deux actifs :
# - Action A : E[R_A] = 0.12, σ_A = 0.20
# - Action B : E[R_B] = 0.08, σ_B = 0.15
#
# Portefeuille : 60% A, 40% B
#
# **a)** Pour ρ(A, B) = 0.5 : calculer E[R_P] et σ_P
# **b)** Refaire pour ρ = -0.3 (hedge)
# **c)** Refaire pour ρ = 0.9 (pas de diversification)
# **d)** Tracer σ_P en fonction de ρ ∈ [-1, 1]
# **e)** Conclusion sur l'effet de la corrélation

# %%
# Votre code ici

# %% [markdown]
# ## 🏆 Exercices Bonus : Applications Avancées
#
# ### Bonus 1 : Paradoxe de Simpson
#
# Démontrer le paradoxe de Simpson avec des données simulées :
# Une corrélation peut s'inverser quand on stratifie par groupes.
#
# **a)** Créer 2 groupes avec tendances opposées
# **b)** Montrer que Corr(X, Y | groupe) > 0 pour chaque groupe
# **c)** Montrer que Corr(X, Y) < 0 globalement
# **d)** Visualiser avec scatter plot coloré par groupe

# %%
# Votre code ici

# %% [markdown]
# ### Bonus 2 : Central Limit Theorem
#
# **a)** Générer n échantillons de Uniforme(0, 1)
# **b)** Calculer la moyenne X̄
# **c)** Répéter 10 000 fois
# **d)** Tracer l'histogramme de X̄ pour n=2, 5, 10, 30, 100
# **e)** Observer la convergence vers une Normale
# **f)** Vérifier : E[X̄] = μ, Var(X̄) = σ²/n

# %%
# Votre code ici

# %% [markdown]
# ### Bonus 3 : Bootstrap
#
# Échantillon de taille n=50 de Exponentielle(2).
#
# **a)** Calculer la moyenne de l'échantillon
# **b)** Générer 1000 échantillons bootstrap (rééchantillonnage avec remise)
# **c)** Calculer la moyenne de chaque échantillon bootstrap
# **d)** Tracer l'histogramme des moyennes bootstrap
# **e)** Calculer un intervalle de confiance à 95% pour la moyenne

# %%
# Votre code ici

# %% [markdown]
# ## 📚 Pour aller plus loin
#
# Consultez le fichier de solutions : `solutions_07_probabilites.ipynb`
#
# Passez ensuite au projet : `projet_07_monte_carlo.ipynb`
#
# ---
#
# **Bon courage ! 💪**
