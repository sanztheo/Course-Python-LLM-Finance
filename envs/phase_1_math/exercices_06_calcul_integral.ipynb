# %% [markdown]
# # 📝 Exercices : Calcul Intégral et Séries
#
# ## 🎯 Objectif
#
# Ces exercices couvrent les 5 parties du Chapitre 06 :
# 1. Intégrales définies et indéfinies
# 2. Techniques d'intégration
# 3. Séries numériques
# 4. Séries de Taylor
# 5. Approximations polynomiales
#
# **Lien vers les solutions** : `solutions_06_calcul_integral.ipynb`

# %%
# 📦 Imports nécessaires
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy import integrate
from sympy import symbols, integrate as sp_integrate, diff, series, exp, sin, cos, log, sqrt, pi, E
from sympy import Sum, oo, factorial, simplify, limit
import seaborn as sns

plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
# %matplotlib inline

print("✅ Bibliothèques chargées!")

# %% [markdown]
# ---
# ## 📐 Section 1 : Intégrales Définies et Indéfinies
#
# ### Exercice 1.1 : Primitives de base ⭐
#
# Calculez les primitives suivantes :
#
# a) $\int x^5 \, dx$
#
# b) $\int \frac{1}{x^3} \, dx$
#
# c) $\int e^{2x} \, dx$
#
# d) $\int \cos(3x) \, dx$
#
# e) $\int \frac{1}{\sqrt{x}} \, dx$

# %%
# 💻 Votre code ici
x = symbols('x')

# a)

# b)

# c)

# d)

# e)

# %% [markdown]
# ### Exercice 1.2 : Intégrales définies simples ⭐
#
# Calculez les intégrales définies suivantes :
#
# a) $\int_0^1 x^3 \, dx$
#
# b) $\int_0^{\pi} \sin(x) \, dx$
#
# c) $\int_1^e \frac{1}{x} \, dx$
#
# d) $\int_{-1}^1 e^x \, dx$

# %%
# 💻 Votre code ici

# %% [markdown]
# ### Exercice 1.3 : Aire sous une courbe ⭐⭐
#
# Calculez l'aire sous la courbe $f(x) = x^2 + 1$ entre $x = 0$ et $x = 3$.
#
# Ensuite, visualisez cette aire avec un graphique.

# %%
# 💻 Votre code ici

# %% [markdown]
# ### Exercice 1.4 : Intégrale et probabilité ⭐⭐
#
# Soit la fonction de densité de probabilité : $f(x) = \frac{1}{2}e^{-|x|}$ pour $x \in \mathbb{R}$.
#
# a) Vérifiez que $\int_{-\infty}^{\infty} f(x) \, dx = 1$
#
# b) Calculez $P(-1 \leq X \leq 1)$
#
# c) Calculez l'espérance $E[X] = \int_{-\infty}^{\infty} x f(x) \, dx$

# %%
# 💻 Votre code ici

# %% [markdown]
# ### Exercice 1.5 : Fonction définie par une intégrale ⭐⭐⭐
#
# Soit $F(x) = \int_0^x t e^{t^2} \, dt$
#
# a) Calculez $F(1)$ et $F(2)$
#
# b) Trouvez $F'(x)$ en utilisant le théorème fondamental du calcul
#
# c) Tracez le graphique de $F(x)$ pour $x \in [0, 2]$

# %%
# 💻 Votre code ici

# %% [markdown]
# ---
# ## 🔧 Section 2 : Techniques d'Intégration
#
# ### Exercice 2.1 : Substitution simple ⭐⭐
#
# Calculez les intégrales suivantes par substitution :
#
# a) $\int x \sqrt{x^2 + 1} \, dx$ (poser $u = x^2 + 1$)
#
# b) $\int \frac{x}{x^2 + 4} \, dx$ (poser $u = x^2 + 4$)
#
# c) $\int e^x \sin(e^x) \, dx$ (poser $u = e^x$)
#
# d) $\int \frac{\ln(x)}{x} \, dx$ (poser $u = \ln(x)$)

# %%
# 💻 Votre code ici

# %% [markdown]
# ### Exercice 2.2 : Intégration par parties ⭐⭐
#
# Calculez les intégrales suivantes par parties :
#
# a) $\int x \cos(x) \, dx$
#
# b) $\int x^2 e^x \, dx$
#
# c) $\int \ln(x) \, dx$
#
# d) $\int x \ln(x) \, dx$

# %%
# 💻 Votre code ici

# %% [markdown]
# ### Exercice 2.3 : Intégration trigonométrique ⭐⭐
#
# Calculez les intégrales suivantes :
#
# a) $\int \sin^2(x) \, dx$ (indice : utilisez $\sin^2(x) = \frac{1 - \cos(2x)}{2}$)
#
# b) $\int \cos^2(x) \, dx$
#
# c) $\int \sin(x) \cos(x) \, dx$

# %%
# 💻 Votre code ici

# %% [markdown]
# ### Exercice 2.4 : Techniques mixtes ⭐⭐⭐
#
# Calculez les intégrales définies suivantes en choisissant la technique appropriée :
#
# a) $\int_0^1 x e^{x^2} \, dx$
#
# b) $\int_0^{\pi/2} x \sin(x) \, dx$
#
# c) $\int_1^2 \frac{\ln(x)}{x^2} \, dx$

# %%
# 💻 Votre code ici

# %% [markdown]
# ### Exercice 2.5 : Application ML - Loss function ⭐⭐⭐
#
# En machine learning, la cross-entropy loss pour une classification binaire est :
#
# $$L(y, \hat{y}) = -y \ln(\hat{y}) - (1-y)\ln(1-\hat{y})$$
#
# où $\hat{y} = \sigma(z) = \frac{1}{1 + e^{-z}}$ (fonction sigmoid).
#
# a) Calculez $\frac{\partial L}{\partial z}$ (utile pour la backpropagation)
#
# b) Montrez que $\frac{\partial \sigma}{\partial z} = \sigma(z)(1 - \sigma(z))$
#
# c) Simplifiez $\frac{\partial L}{\partial z}$

# %%
# 💻 Votre code ici

# %% [markdown]
# ---
# ## 📊 Section 3 : Séries Numériques
#
# ### Exercice 3.1 : Convergence de séries géométriques ⭐
#
# Déterminez si les séries suivantes convergent et, si oui, trouvez leur somme :
#
# a) $\sum_{n=0}^{\infty} \left(\frac{1}{3}\right)^n$
#
# b) $\sum_{n=0}^{\infty} \left(\frac{2}{3}\right)^n$
#
# c) $\sum_{n=0}^{\infty} 2^n$
#
# d) $\sum_{n=1}^{\infty} \frac{3}{4^n}$

# %%
# 💻 Votre code ici

# %% [markdown]
# ### Exercice 3.2 : Test du terme général ⭐⭐
#
# Utilisez le test du terme général pour montrer que les séries suivantes divergent :
#
# a) $\sum_{n=1}^{\infty} \frac{n}{n+1}$
#
# b) $\sum_{n=1}^{\infty} \cos(n)$
#
# c) $\sum_{n=1}^{\infty} \frac{n^2}{n^2 + 1}$

# %%
# 💻 Votre code ici

# %% [markdown]
# ### Exercice 3.3 : Série de Riemann ⭐⭐
#
# Pour la série de Riemann $\sum_{n=1}^{\infty} \frac{1}{n^p}$ :
#
# a) Calculez numériquement les sommes partielles $S_N$ pour $N = 10, 100, 1000$ et $p = 2$
#
# b) Comparez avec la valeur théorique $\frac{\pi^2}{6}$
#
# c) Visualisez la convergence pour $p = 2, 3, 4$

# %%
# 💻 Votre code ici

# %% [markdown]
# ### Exercice 3.4 : Test du rapport ⭐⭐⭐
#
# Utilisez le test du rapport pour déterminer la convergence des séries suivantes :
#
# a) $\sum_{n=1}^{\infty} \frac{n!}{n^n}$
#
# b) $\sum_{n=1}^{\infty} \frac{2^n}{n!}$
#
# c) $\sum_{n=1}^{\infty} \frac{n^n}{n!}$
#
# Pour chaque série, calculez $L = \lim_{n \to \infty} \left|\frac{u_{n+1}}{u_n}\right|$

# %%
# 💻 Votre code ici

# %% [markdown]
# ### Exercice 3.5 : Application - Somme infinie en programmation ⭐⭐
#
# En informatique, on utilise souvent des approximations de séries infinies.
#
# a) Écrivez une fonction qui calcule $e^x$ en utilisant la série : $e^x = \sum_{n=0}^{\infty} \frac{x^n}{n!}$
#
# b) Arrêtez la somme quand le terme devient inférieur à $10^{-10}$
#
# c) Comparez avec `np.exp(x)` pour $x = 0.5, 1, 2$
#
# d) Combien de termes sont nécessaires pour chaque valeur de $x$ ?

# %%
# 💻 Votre code ici

# %% [markdown]
# ---
# ## 🎨 Section 4 : Séries de Taylor
#
# ### Exercice 4.1 : Développements de Taylor de base ⭐⭐
#
# Calculez les développements de Taylor à l'ordre 5 autour de $x = 0$ pour :
#
# a) $f(x) = e^{2x}$
#
# b) $f(x) = \sin(2x)$
#
# c) $f(x) = \ln(1 + x)$
#
# d) $f(x) = \sqrt{1 + x}$

# %%
# 💻 Votre code ici

# %% [markdown]
# ### Exercice 4.2 : Approximation de fonctions ⭐⭐
#
# Pour $f(x) = \cos(x)$ :
#
# a) Calculez les approximations de Taylor d'ordres 2, 4, 6, 8
#
# b) Tracez ces approximations avec la fonction exacte sur $[-2\pi, 2\pi]$
#
# c) Pour quelle valeur de $x$ l'approximation d'ordre 4 a-t-elle une erreur de 0.01 ?

# %%
# 💻 Votre code ici

# %% [markdown]
# ### Exercice 4.3 : Série de Taylor autour d'un autre point ⭐⭐⭐
#
# Calculez le développement de Taylor de $f(x) = \ln(x)$ autour de $a = 1$ jusqu'à l'ordre 4.
#
# a) Calculez les dérivées successives en $x = 1$
#
# b) Écrivez le polynôme de Taylor
#
# c) Estimez $\ln(1.2)$ avec cette approximation
#
# d) Comparez avec la valeur exacte

# %%
# 💻 Votre code ici

# %% [markdown]
# ### Exercice 4.4 : Approximation de la fonction tanh ⭐⭐⭐
#
# La fonction $\tanh(x) = \frac{e^x - e^{-x}}{e^x + e^{-x}}$ est souvent utilisée comme fonction d'activation.
#
# a) Calculez le développement de Taylor de $\tanh(x)$ à l'ordre 7
#
# b) Montrez que seuls les termes impairs sont non nuls
#
# c) Visualisez $\tanh(x)$ et ses approximations d'ordres 1, 3, 5, 7 sur $[-3, 3]$
#
# d) Pour quelle plage de $x$ l'approximation d'ordre 3 est-elle précise à 0.01 près ?

# %%
# 💻 Votre code ici

# %% [markdown]
# ### Exercice 4.5 : Identité d'Euler via Taylor ⭐⭐⭐
#
# L'identité d'Euler $e^{i\theta} = \cos(\theta) + i\sin(\theta)$ peut être dérivée des séries de Taylor.
#
# a) Développez $e^{i\theta}$ en série de Taylor (où $i^2 = -1$)
#
# b) Séparez les termes réels et imaginaires
#
# c) Montrez que la partie réelle donne $\cos(\theta)$ et la partie imaginaire donne $\sin(\theta)$
#
# d) Vérifiez numériquement pour $\theta = \pi$ que $e^{i\pi} + 1 = 0$ (la formule d'Euler)

# %%
# 💻 Votre code ici

# %% [markdown]
# ---
# ## 🔬 Section 5 : Approximations Polynomiales
#
# ### Exercice 5.1 : Analyse de l'erreur ⭐⭐
#
# Pour $f(x) = e^x$ et son approximation de Taylor d'ordre $n$ autour de $x = 0$ :
#
# a) Calculez l'erreur absolue pour $x = 1$ avec $n = 1, 2, 3, 4, 5$
#
# b) Calculez l'erreur relative : $\epsilon_r = \frac{|f(x) - P_n(x)|}{|f(x)|}$
#
# c) Tracez l'erreur en fonction de $n$ (échelle logarithmique)
#
# d) Combien de termes sont nécessaires pour une erreur < $10^{-6}$ ?

# %%
# 💻 Votre code ici

# %% [markdown]
# ### Exercice 5.2 : Rayon de convergence ⭐⭐⭐
#
# Pour $f(x) = \frac{1}{1-x}$ :
#
# a) Développez en série de Taylor autour de $x = 0$ (série géométrique)
#
# b) Calculez les approximations d'ordres 5 et 10
#
# c) Tracez l'erreur en fonction de $x$ pour $x \in [-2, 2]$
#
# d) Identifiez le rayon de convergence (où l'erreur explose)
#
# e) Expliquez pourquoi la série diverge pour $|x| \geq 1$

# %%
# 💻 Votre code ici

# %% [markdown]
# ### Exercice 5.3 : Approximation optimale ⭐⭐⭐
#
# Vous voulez approximer $f(x) = \sin(x)$ sur $[0, \pi]$ avec une erreur maximale de $10^{-3}$.
#
# a) Quel ordre d'approximation de Taylor est nécessaire ?
#
# b) Tracez l'erreur maximale en fonction de l'ordre
#
# c) Comparez le nombre d'opérations pour évaluer le polynôme vs `np.sin()`
#
# d) Dans quel cas l'approximation polynomiale est-elle avantageuse ?

# %%
# 💻 Votre code ici

# %% [markdown]
# ### Exercice 5.4 : Application Finance - Approximation de Black-Scholes ⭐⭐⭐
#
# La formule de Black-Scholes pour le prix d'une option call utilise la CDF normale $\Phi(x)$.
#
# Pour de petites valeurs de $x$, on peut approximer :
#
# $$\Phi(x) \approx \frac{1}{2} + \frac{1}{\sqrt{2\pi}} \left(x - \frac{x^3}{6} + \frac{x^5}{40} - \cdots\right)$$
#
# a) Implémentez cette approximation d'ordre 5
#
# b) Comparez avec `scipy.stats.norm.cdf()` pour $x \in [-2, 2]$
#
# c) Tracez l'erreur absolue
#
# d) Pour quelle plage de $x$ l'erreur est-elle < $10^{-4}$ ?

# %%
# 💻 Votre code ici

# %% [markdown]
# ### Exercice 5.5 : Projet Mini - Calculatrice d'approximations ⭐⭐⭐
#
# Créez une fonction `approximer(f, x, ordre, a=0)` qui :
#
# a) Calcule l'approximation de Taylor de `f` autour de `a` à l'ordre donné
#
# b) Évalue cette approximation en `x`
#
# c) Retourne la valeur approximée, la valeur exacte, et l'erreur
#
# d) Testez votre fonction sur :
#    - $\sin(0.5)$ avec ordres 3, 5, 7
#    - $e^{0.2}$ avec ordres 2, 4, 6
#    - $\ln(1.1)$ autour de $a=1$ avec ordres 3, 5
#
# e) Créez un tableau comparatif avec les résultats

# %%
# 💻 Votre code ici

# %% [markdown]
# ---
# ## 🎯 Exercices Bonus
#
# ### Bonus 1 : Intégration numérique vs symbolique ⭐⭐⭐
#
# Comparez les méthodes d'intégration numérique (trapèzes, Simpson) avec l'intégration symbolique pour :
#
# $$\int_0^1 e^{-x^2} \, dx$$
#
# Cette intégrale n'a pas de forme close mais est importante en probabilité.

# %%
# 💻 Votre code ici

# %% [markdown]
# ### Bonus 2 : Série de Fourier ⭐⭐⭐
#
# Les séries de Fourier sont une généralisation des séries de Taylor pour les fonctions périodiques.
#
# Pour une fonction $2\pi$-périodique : $f(x) = \sum_{n=-\infty}^{\infty} c_n e^{inx}$
#
# Approximez la fonction carrée (square wave) et visualisez la convergence.

# %%
# 💻 Votre code ici

# %% [markdown]
# ### Bonus 3 : Calcul de π par séries ⭐⭐⭐
#
# Il existe plusieurs séries qui convergent vers $\pi$ :
#
# a) Formule de Leibniz : $\frac{\pi}{4} = 1 - \frac{1}{3} + \frac{1}{5} - \frac{1}{7} + \cdots$
#
# b) Formule de Wallis : $\frac{\pi}{2} = \prod_{n=1}^{\infty} \frac{4n^2}{4n^2 - 1}$
#
# c) Série de Ramanujan : $\frac{1}{\pi} = \frac{2\sqrt{2}}{9801} \sum_{n=0}^{\infty} \frac{(4n)!(1103 + 26390n)}{(n!)^4 396^{4n}}$
#
# Implémentez ces trois méthodes et comparez leur vitesse de convergence.

# %%
# 💻 Votre code ici

# %% [markdown]
# ---
# ## 📊 Auto-évaluation
#
# Une fois tous les exercices terminés, évaluez votre compréhension :
#
# - ✅ Je sais calculer des intégrales définies et indéfinies
# - ✅ Je maîtrise l'intégration par substitution et par parties
# - ✅ Je comprends la convergence des séries numériques
# - ✅ Je sais développer des fonctions en séries de Taylor
# - ✅ Je peux analyser l'erreur d'approximation
# - ✅ Je comprends les applications en ML et finance
#
# **Prochaine étape** : Consultez les solutions détaillées dans `solutions_06_calcul_integral.ipynb`
#
# **Projet** : Appliquez vos connaissances dans `projet_06_approximation_fonctions.ipynb`
