# %% [markdown]
# # 📚 Exercices - Les Bases des Mathématiques
#
# Bienvenue dans vos premiers exercices de mathématiques ! 🎯
#
# ## 📝 Instructions Générales
#
# - **Écrivez votre code Python** dans les cellules vides prévues à cet effet
# - **Utilisez `print()`** pour afficher vos résultats
# - **Exécutez chaque cellule** avec `Shift + Enter` pour vérifier votre réponse
# - **N'hésitez pas à expérimenter** : essayer, se tromper et recommencer fait partie de l'apprentissage !
# - **Les indices** sont disponibles dans les cellules commentées (cherchez les `# INDICE :`)
#
# ## 🎯 Objectifs d'Apprentissage
#
# À la fin de ces exercices, vous serez capable de :
# - ✅ Identifier et manipuler différents types de nombres
# - ✅ Appliquer correctement la priorité des opérations (PEMDAS)
# - ✅ Utiliser les puissances et leurs règles
# - ✅ Calculer et manipuler des racines carrées
# - ✅ Travailler avec des variables et expressions algébriques
# - ✅ Résoudre des équations simples
#
# ---
#
# **💡 Conseil :** Prenez votre temps, lisez bien chaque énoncé, et n'oubliez pas de tester votre code !

# %% [markdown]
# ## 📌 Section 1 : Rappel des Concepts
#
# Avant de commencer les exercices, voici un bref rappel des concepts importants :
#
# ### Types de Nombres
# - **Entiers naturels** ($\mathbb{N}$) : 0, 1, 2, 3, ...
# - **Entiers relatifs** ($\mathbb{Z}$) : ..., -2, -1, 0, 1, 2, ...
# - **Nombres décimaux** : 3.14, -2.5, 0.001
# - **Fractions/Rationnels** ($\mathbb{Q}$) : $\frac{1}{2}$, $\frac{3}{4}$, $\frac{-5}{7}$
#
# ### Priorité des Opérations (PEMDAS)
# 1. **P**arenthèses : $(\quad)$
# 2. **E**xposants : $x^2$, $2^3$
# 3. **M**ultiplication et **D**ivision : $\times$, $\div$ (de gauche à droite)
# 4. **A**ddition et **S**oustraction : $+$, $-$ (de gauche à droite)
#
# ### Règles des Puissances
# 1. **Multiplication** : $a^m \times a^n = a^{m+n}$
# 2. **Division** : $\frac{a^m}{a^n} = a^{m-n}$
# 3. **Puissance de puissance** : $(a^m)^n = a^{m \times n}$
#
# ### Racines Carrées
# - $\sqrt{a^2} = |a|$ (valeur absolue)
# - $\sqrt{a} \times \sqrt{b} = \sqrt{a \times b}$
# - En Python : `import math` puis `math.sqrt(x)` ou `x ** 0.5`

# %% [markdown]
# ---
#
# ## 🔢 Section 2 : Types de Nombres
#
# Dans cette section, vous allez identifier et manipuler différents types de nombres.

# %% [markdown]
# ### Exercice 1.1 : Classification des Nombres
#
# **Consigne :** Créez des variables pour chaque type de nombre et affichez-les.
#
# - Créez `entier_naturel` avec la valeur 42
# - Créez `entier_negatif` avec la valeur -15
# - Créez `nombre_decimal` avec la valeur 3.14159
# - Créez `fraction` avec la valeur $\frac{3}{4}$ (calculée en division)
#
# Affichez chaque variable avec son type en utilisant `type()`.

# %%
# Exercice 1.1 : Écrivez votre code ici

# INDICE : Utilisez print() pour afficher et type() pour voir le type
# Exemple : print(f"Ma variable : {ma_var}, Type : {type(ma_var)}")

# %% [markdown]
# ### Exercice 1.2 : Opérations de Base
#
# **Consigne :** Calculez et affichez les résultats suivants :
#
# 1. $25 + 17$
# 2. $100 - 63$
# 3. $12 \times 8$
# 4. $144 \div 12$
# 5. Le reste de $17 \div 5$ (utilisez l'opérateur `%`)

# %%
# Exercice 1.2 : Écrivez votre code ici

# INDICE : L'opérateur % donne le reste de la division
# Exemple : 10 % 3 donne 1 (car 10 = 3×3 + 1)

# %% [markdown]
# ### Exercice 1.3 : Comparaison de Nombres
#
# **Consigne :** Utilisez les opérateurs de comparaison pour vérifier si :
#
# 1. $15$ est plus grand que $10$
# 2. $7$ est égal à $3 + 4$
# 3. $20$ est différent de $19$
# 4. $\frac{1}{2}$ est plus petit que $\frac{3}{4}$
#
# Les résultats doivent être `True` ou `False`.

# %%
# Exercice 1.3 : Écrivez votre code ici

# INDICE : Opérateurs de comparaison
# > (plus grand), < (plus petit), == (égal), != (différent)
# >= (plus grand ou égal), <= (plus petit ou égal)

# %% [markdown]
# ### Exercice 1.4 : Conversion de Types
#
# **Consigne :**
#
# 1. Créez une variable `x = 5.7`
# 2. Convertissez-la en entier et stockez le résultat dans `x_entier`
# 3. Créez une variable `y = 10`
# 4. Convertissez-la en décimal et stockez le résultat dans `y_decimal`
# 5. Affichez les résultats et leurs types

# %%
# Exercice 1.4 : Écrivez votre code ici

# INDICE : Utilisez int() pour convertir en entier
# Utilisez float() pour convertir en décimal

# %% [markdown]
# ### Exercice 1.5 : Valeur Absolue
#
# **Consigne :** Calculez la valeur absolue des nombres suivants :
#
# 1. $|-15|$
# 2. $|23|$
# 3. $|-7.5|$
# 4. $|0|$
#
# Utilisez la fonction `abs()` de Python.

# %%
# Exercice 1.5 : Écrivez votre code ici

# INDICE : abs(x) retourne la valeur absolue de x

# %% [markdown]
# ---
#
# ## ⚖️ Section 3 : Priorité des Opérations (PEMDAS)
#
# Appliquez correctement l'ordre des opérations pour obtenir les bons résultats.

# %% [markdown]
# ### Exercice 2.1 : Calculs Simples avec PEMDAS
#
# **Consigne :** Calculez les expressions suivantes **sans modifier l'ordre** :
#
# 1. $3 + 5 \times 2$
# 2. $(3 + 5) \times 2$
# 3. $20 - 4 \times 3$
# 4. $(20 - 4) \times 3$
#
# Observez la différence que font les parenthèses !

# %%
# Exercice 2.1 : Écrivez votre code ici

# INDICE : Python respecte automatiquement PEMDAS
# Tapez simplement les expressions telles quelles

# %% [markdown]
# ### Exercice 2.2 : Expressions Complexes
#
# **Consigne :** Calculez les expressions suivantes :
#
# 1. $10 + 2 \times 5 - 3$
# 2. $10 + 2 \times (5 - 3)$
# 3. $(10 + 2) \times (5 - 3)$
# 4. $100 \div 5 \times 2$
# 5. $100 \div (5 \times 2)$

# %%
# Exercice 2.2 : Écrivez votre code ici

# INDICE : Attention à la division et multiplication !
# Elles s'exécutent de gauche à droite

# %% [markdown]
# ### Exercice 2.3 : Avec des Exposants
#
# **Consigne :** Calculez les expressions suivantes (utilisez `**` pour les puissances) :
#
# 1. $2 + 3^2$
# 2. $(2 + 3)^2$
# 3. $5 \times 2^3$
# 4. $(5 \times 2)^3$
# 5. $100 - 4^2 \div 2$

# %%
# Exercice 2.3 : Écrivez votre code ici

# INDICE : En Python, utilisez ** pour les puissances
# Exemple : 2**3 = 2³ = 8

# %% [markdown]
# ### Exercice 2.4 : Trouver les Parenthèses Manquantes
#
# **Consigne :** Ajoutez des parenthèses pour obtenir le résultat indiqué :
#
# 1. $2 + 3 \times 4 = 20$ (Résultat attendu : 20)
# 2. $10 - 2 \times 3 = 24$ (Résultat attendu : 24)
# 3. $6 \div 2 + 1 = 2$ (Résultat attendu : 2)
# 4. $5 + 3 \times 2 - 1 = 15$ (Résultat attendu : 15)

# %%
# Exercice 2.4 : Écrivez votre code ici

# INDICE : Testez différentes combinaisons de parenthèses
# jusqu'à obtenir le résultat attendu

# %% [markdown]
# ### Exercice 2.5 : Expression Complète
#
# **Consigne :** Calculez cette expression étape par étape :
#
# $$\frac{(8 + 2) \times 3 - 5^2}{2}$$
#
# 1. D'abord, calculez l'expression complète en une fois
# 2. Ensuite, décomposez le calcul en étapes intermédiaires avec des variables

# %%
# Exercice 2.5 : Écrivez votre code ici

# INDICE : Décomposition suggérée :
# etape1 = 8 + 2
# etape2 = etape1 * 3
# etape3 = 5 ** 2
# etc...

# %% [markdown]
# ---
#
# ## 🚀 Section 4 : Puissances et leurs Règles
#
# Maîtrisez les trois règles fondamentales des puissances.

# %% [markdown]
# ### Exercice 3.1 : Règle 1 - Multiplication de Puissances
#
# **Règle :** $a^m \times a^n = a^{m+n}$
#
# **Consigne :** Calculez en utilisant la règle, puis vérifiez avec Python :
#
# 1. $2^3 \times 2^4$
# 2. $5^2 \times 5^3$
# 3. $10^1 \times 10^2 \times 10^3$
# 4. $3^5 \times 3^{-2}$

# %%
# Exercice 3.1 : Écrivez votre code ici

# INDICE : Calculez d'abord avec la règle
# Exemple : 2^3 × 2^4 = 2^(3+4) = 2^7
# Puis vérifiez : 2**7

# %% [markdown]
# ### Exercice 3.2 : Règle 2 - Division de Puissances
#
# **Règle :** $\frac{a^m}{a^n} = a^{m-n}$
#
# **Consigne :** Calculez en utilisant la règle, puis vérifiez avec Python :
#
# 1. $\frac{5^7}{5^3}$
# 2. $\frac{3^6}{3^2}$
# 3. $\frac{10^5}{10^3}$
# 4. $\frac{2^4}{2^6}$ (résultat avec exposant négatif)

# %%
# Exercice 3.2 : Écrivez votre code ici

# INDICE : Pour la division, utilisez /
# Exemple : 5**7 / 5**3
# Ou simplifiez d'abord : 5^(7-3) = 5^4

# %% [markdown]
# ### Exercice 3.3 : Règle 3 - Puissance de Puissance
#
# **Règle :** $(a^m)^n = a^{m \times n}$
#
# **Consigne :** Calculez en utilisant la règle, puis vérifiez avec Python :
#
# 1. $(2^3)^2$
# 2. $(5^2)^4$
# 3. $(10^3)^2$
# 4. $((3^2)^2)^2$

# %%
# Exercice 3.3 : Écrivez votre code ici

# INDICE : Deux façons de calculer
# 1. Direct : (2**3)**2
# 2. Avec la règle : 2**(3*2) = 2**6

# %% [markdown]
# ### Exercice 3.4 : Combiner les Trois Règles
#
# **Consigne :** Simplifiez puis calculez les expressions suivantes :
#
# 1. $\frac{2^5 \times 2^3}{2^4}$
# 2. $(3^2)^3 \times 3^{-4}$
# 3. $\frac{(5^2)^3}{5^4}$
# 4. $2^3 \times (2^2)^2 \div 2^5$

# %%
# Exercice 3.4 : Écrivez votre code ici

# INDICE : Simplifiez d'abord en appliquant les règles
# Puis calculez le résultat final
# Vous pouvez décomposer en étapes intermédiaires

# %% [markdown]
# ### Exercice 3.5 : Puissances de 10
#
# **Consigne :** Les puissances de 10 sont très utiles en sciences. Calculez :
#
# 1. $10^3$ (mille)
# 2. $10^6$ (million)
# 3. $10^{-3}$ (millième)
# 4. $10^9$ (milliard)
# 5. Écrivez le nombre 3 500 000 en notation scientifique : $3.5 \times 10^?$

# %%
# Exercice 3.5 : Écrivez votre code ici

# INDICE : Pour la notation scientifique
# Comptez combien de zéros ou de décimales
# 3 500 000 = 3.5 × 10^?

# %% [markdown]
# ### Exercice 3.6 : Croissance Exponentielle
#
# **Consigne :** Une population de bactéries double chaque heure. Si on commence avec 1 bactérie :
#
# 1. Combien y a-t-il de bactéries après 1 heure ? ($2^1$)
# 2. Après 5 heures ? ($2^5$)
# 3. Après 10 heures ? ($2^{10}$)
# 4. Après 20 heures ? ($2^{20}$)
#
# Calculez et observez la croissance !

# %%
# Exercice 3.6 : Écrivez votre code ici

# INDICE : La formule est population = 2^heures
# Calculez 2**1, 2**5, 2**10, 2**20

# %% [markdown]
# ---
#
# ## √ Section 5 : Racines Carrées
#
# Explorez les racines carrées et leurs propriétés.

# %% [markdown]
# ### Exercice 4.1 : Racines Carrées Simples
#
# **Consigne :** Calculez les racines carrées suivantes avec Python :
#
# 1. $\sqrt{16}$
# 2. $\sqrt{25}$
# 3. $\sqrt{100}$
# 4. $\sqrt{144}$
# 5. $\sqrt{2}$ (résultat décimal)
#
# Utilisez `import math` puis `math.sqrt()` ou l'opérateur `** 0.5`

# %%
# Exercice 4.1 : Écrivez votre code ici

# INDICE : Deux méthodes possibles
# Méthode 1 : import math, puis math.sqrt(16)
# Méthode 2 : 16 ** 0.5

# %% [markdown]
# ### Exercice 4.2 : Relation entre Puissance et Racine
#
# **Consigne :** Vérifiez que $\sqrt{x} = x^{\frac{1}{2}}$ en calculant :
#
# 1. $\sqrt{49}$ et $49^{0.5}$
# 2. $\sqrt{64}$ et $64^{0.5}$
# 3. $\sqrt{81}$ et $81^{0.5}$
#
# Les résultats doivent être identiques !

# %%
# Exercice 4.2 : Écrivez votre code ici

# INDICE : Comparez les deux méthodes
# math.sqrt(49) devrait donner le même résultat que 49**0.5

# %% [markdown]
# ### Exercice 4.3 : Propriété du Produit
#
# **Règle :** $\sqrt{a} \times \sqrt{b} = \sqrt{a \times b}$
#
# **Consigne :** Vérifiez cette propriété avec :
#
# 1. $\sqrt{4} \times \sqrt{9}$ et $\sqrt{4 \times 9}$
# 2. $\sqrt{16} \times \sqrt{25}$ et $\sqrt{16 \times 25}$
# 3. $\sqrt{2} \times \sqrt{8}$ et $\sqrt{2 \times 8}$

# %%
# Exercice 4.3 : Écrivez votre code ici

# INDICE : Calculez les deux côtés de l'égalité
# Gauche : math.sqrt(4) * math.sqrt(9)
# Droite : math.sqrt(4 * 9)

# %% [markdown]
# ### Exercice 4.4 : Simplification de Racines
#
# **Consigne :** Simplifiez puis calculez :
#
# 1. $\sqrt{8}$ (sachant que $8 = 4 \times 2$)
# 2. $\sqrt{18}$ (sachant que $18 = 9 \times 2$)
# 3. $\sqrt{50}$ (sachant que $50 = 25 \times 2$)
# 4. $\sqrt{75}$ (sachant que $75 = 25 \times 3$)
#
# Utilisez la propriété $\sqrt{a \times b} = \sqrt{a} \times \sqrt{b}$

# %%
# Exercice 4.4 : Écrivez votre code ici

# INDICE : Décomposez en facteurs
# √8 = √(4×2) = √4 × √2 = 2√2 ≈ 2 × 1.414...
# Calculez avec math.sqrt(4) * math.sqrt(2)

# %% [markdown]
# ### Exercice 4.5 : Théorème de Pythagore
#
# **Théorème :** Dans un triangle rectangle, $a^2 + b^2 = c^2$ où $c$ est l'hypoténuse.
#
# **Consigne :** Trouvez la longueur de l'hypoténuse $c$ pour :
#
# 1. $a = 3$, $b = 4$ → $c = \sqrt{3^2 + 4^2}$
# 2. $a = 5$, $b = 12$ → $c = \sqrt{5^2 + 12^2}$
# 3. $a = 6$, $b = 8$ → $c = \sqrt{6^2 + 8^2}$
# 4. $a = 7$, $b = 24$ → $c = \sqrt{7^2 + 24^2}$

# %%
# Exercice 4.5 : Écrivez votre code ici

# INDICE : Formule : c = sqrt(a² + b²)
# En Python : c = math.sqrt(a**2 + b**2)

# %% [markdown]
# ---
#
# ## 📐 Section 6 : Variables et Expressions Algébriques
#
# Apprenez à travailler avec des variables mathématiques en Python.

# %% [markdown]
# ### Exercice 5.1 : Évaluation d'Expressions
#
# **Consigne :** Évaluez les expressions suivantes pour $x = 5$ :
#
# 1. $2x + 3$
# 2. $x^2 - 4$
# 3. $3x^2 + 2x - 1$
# 4. $\frac{x^2 + 1}{2}$

# %%
# Exercice 5.1 : Écrivez votre code ici

# INDICE : Définissez x = 5
# Puis calculez chaque expression
# Exemple : resultat1 = 2*x + 3

# %% [markdown]
# ### Exercice 5.2 : Expressions avec Deux Variables
#
# **Consigne :** Pour $x = 3$ et $y = 7$, calculez :
#
# 1. $x + y$
# 2. $x \times y$
# 3. $x^2 + y^2$
# 4. $(x + y)^2$
# 5. $2x + 3y - 5$

# %%
# Exercice 5.2 : Écrivez votre code ici

# INDICE : Définissez x = 3 et y = 7
# Puis calculez chaque expression

# %% [markdown]
# ### Exercice 5.3 : Identité Remarquable - Carré d'une Somme
#
# **Identité :** $(a + b)^2 = a^2 + 2ab + b^2$
#
# **Consigne :** Vérifiez cette identité pour $a = 4$ et $b = 3$ :
#
# 1. Calculez $(a + b)^2$ directement
# 2. Calculez $a^2 + 2ab + b^2$
# 3. Vérifiez qu'ils sont égaux

# %%
# Exercice 5.3 : Écrivez votre code ici

# INDICE : Calculez les deux méthodes
# gauche = (a + b)**2
# droite = a**2 + 2*a*b + b**2

# %% [markdown]
# ### Exercice 5.4 : Identité Remarquable - Différence de Carrés
#
# **Identité :** $a^2 - b^2 = (a + b)(a - b)$
#
# **Consigne :** Vérifiez cette identité pour $a = 8$ et $b = 5$ :
#
# 1. Calculez $a^2 - b^2$
# 2. Calculez $(a + b)(a - b)$
# 3. Vérifiez qu'ils sont égaux

# %%
# Exercice 5.4 : Écrivez votre code ici

# INDICE : Deux façons de calculer
# gauche = a**2 - b**2
# droite = (a + b) * (a - b)

# %% [markdown]
# ### Exercice 5.5 : Fonction Mathématique
#
# **Consigne :** Créez une fonction Python qui calcule $f(x) = 2x^2 - 3x + 1$
#
# Testez votre fonction avec :
# 1. $f(0)$
# 2. $f(1)$
# 3. $f(2)$
# 4. $f(-1)$
# 5. $f(10)$

# %%
# Exercice 5.5 : Écrivez votre code ici

# INDICE : Créez une fonction
# def f(x):
#     return 2*x**2 - 3*x + 1
#
# Puis testez : print(f(0)), print(f(1)), etc.

# %% [markdown]
# ### Exercice 5.6 : Substitution de Variables
#
# **Consigne :** Sachant que $a = 2x + 1$, évaluez $3a - 5$ pour $x = 4$
#
# 1. Calculez d'abord $a$ en fonction de $x$
# 2. Puis calculez $3a - 5$
# 3. Vérifiez en substituant directement : $3(2x + 1) - 5$

# %%
# Exercice 5.6 : Écrivez votre code ici

# INDICE : Deux méthodes possibles
# Méthode 1 : Calculez a, puis 3*a - 5
# Méthode 2 : Substituez directement 3*(2*x + 1) - 5

# %% [markdown]
# ---
#
# ## ⚖️ Section 7 : Résolution d'Équations Simples
#
# Apprenez à résoudre trois types d'équations de base.

# %% [markdown]
# ### Exercice 6.1 : Type 1 - Isoler la Variable (Addition/Soustraction)
#
# **Méthode :** Pour résoudre $x + a = b$, on fait $x = b - a$
#
# **Consigne :** Résolvez les équations suivantes (trouvez la valeur de $x$) :
#
# 1. $x + 5 = 12$
# 2. $x - 7 = 3$
# 3. $15 = x + 8$
# 4. $x + 3.5 = 10$
#
# Vérifiez vos réponses en substituant la valeur trouvée dans l'équation originale.

# %%
# Exercice 6.1 : Écrivez votre code ici

# INDICE : Pour x + 5 = 12
# Solution : x = 12 - 5
# Vérification : x + 5 == 12 (doit donner True)

# %% [markdown]
# ### Exercice 6.2 : Type 2 - Isoler la Variable (Multiplication/Division)
#
# **Méthode :** Pour résoudre $ax = b$, on fait $x = \frac{b}{a}$
#
# **Consigne :** Résolvez les équations suivantes :
#
# 1. $3x = 15$
# 2. $\frac{x}{4} = 5$
# 3. $7x = 49$
# 4. $\frac{x}{2} = 3.5$
#
# Vérifiez vos réponses.

# %%
# Exercice 6.2 : Écrivez votre code ici

# INDICE : Pour 3x = 15
# Solution : x = 15 / 3
# Pour x/4 = 5, multipliez par 4 : x = 5 * 4

# %% [markdown]
# ### Exercice 6.3 : Type 3 - Équations à Deux Étapes
#
# **Méthode :** Pour $ax + b = c$
# 1. D'abord soustraire $b$ : $ax = c - b$
# 2. Puis diviser par $a$ : $x = \frac{c - b}{a}$
#
# **Consigne :** Résolvez les équations suivantes :
#
# 1. $2x + 3 = 11$
# 2. $5x - 7 = 18$
# 3. $3x + 4 = 19$
# 4. $4x - 5 = 15$
#
# Vérifiez vos réponses.

# %%
# Exercice 6.3 : Écrivez votre code ici

# INDICE : Pour 2x + 3 = 11
# Étape 1 : 2x = 11 - 3
# Étape 2 : x = (11 - 3) / 2
# Vérification : 2*x + 3 == 11

# %% [markdown]
# ### Exercice 6.4 : Équations avec Fractions
#
# **Consigne :** Résolvez les équations suivantes :
#
# 1. $\frac{x}{3} + 2 = 5$
# 2. $\frac{2x}{5} = 4$
# 3. $\frac{x + 1}{2} = 3$
# 4. $\frac{3x - 1}{4} = 2$
#
# Vérifiez vos réponses.

# %%
# Exercice 6.4 : Écrivez votre code ici

# INDICE : Pour x/3 + 2 = 5
# Étape 1 : x/3 = 5 - 2
# Étape 2 : x = (5 - 2) * 3

# %% [markdown]
# ### Exercice 6.5 : Équations avec Variables des Deux Côtés
#
# **Méthode :** Pour $ax + b = cx + d$
# 1. Regrouper les $x$ d'un côté : $ax - cx = d - b$
# 2. Factoriser : $(a - c)x = d - b$
# 3. Diviser : $x = \frac{d - b}{a - c}$
#
# **Consigne :** Résolvez les équations suivantes :
#
# 1. $3x + 5 = 2x + 8$
# 2. $5x - 3 = 2x + 9$
# 3. $7x + 1 = 4x + 13$
# 4. $6x - 5 = 3x + 7$

# %%
# Exercice 6.5 : Écrivez votre code ici

# INDICE : Pour 3x + 5 = 2x + 8
# Étape 1 : 3x - 2x = 8 - 5
# Étape 2 : x = 8 - 5
# Vérification : 3*x + 5 == 2*x + 8

# %% [markdown]
# ### Exercice 6.6 : Problème Appliqué
#
# **Problème :** Marie a 3 fois plus de billes que Tom. Ensemble, ils ont 24 billes. Combien de billes a chacun ?
#
# **Consigne :**
# 1. Posez $x$ = nombre de billes de Tom
# 2. Exprimez le nombre de billes de Marie en fonction de $x$
# 3. Écrivez l'équation : $x + 3x = 24$
# 4. Résolvez pour trouver $x$
# 5. Calculez le nombre de billes de Marie
# 6. Vérifiez que le total fait bien 24

# %%
# Exercice 6.6 : Écrivez votre code ici

# INDICE : 
# Tom : x billes
# Marie : 3x billes
# Total : x + 3x = 24
# Donc : 4x = 24
# Donc : x = 24 / 4

# %% [markdown]
# ---
#
# ## 🎉 Félicitations !
#
# Vous avez terminé tous les exercices sur les bases des mathématiques ! 🎊
#
# ### 📊 Ce que vous avez accompli :
#
# ✅ **Section 1** : Maîtrise des types de nombres et opérations de base
# ✅ **Section 2** : Application correcte de la priorité des opérations (PEMDAS)
# ✅ **Section 3** : Compréhension des puissances et leurs trois règles fondamentales
# ✅ **Section 4** : Manipulation des racines carrées et leurs propriétés
# ✅ **Section 5** : Travail avec variables et expressions algébriques
# ✅ **Section 6** : Résolution d'équations simples (3 types différents)
#
# ### 🚀 Prochaines Étapes :
#
# 1. **Vérifiez vos réponses** avec le fichier `solutions_01_bases.ipynb`
# 2. **Revoyez les exercices** où vous avez eu des difficultés
# 3. **Pratiquez encore** : La répétition est la clé de la maîtrise !
# 4. **Passez au cours suivant** une fois que vous vous sentez à l'aise
#
# ### 💡 Conseils pour la Suite :
#
# - Ne vous découragez pas si certains exercices étaient difficiles
# - Les mathématiques, ça se construit petit à petit
# - Revenez sur ce notebook quand vous en avez besoin
# - N'hésitez pas à créer vos propres exercices pour pratiquer
#
# ---
#
# **Excellent travail ! Continuez comme ça ! 🌟**
